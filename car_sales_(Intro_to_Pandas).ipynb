# %% [markdown]
# <a href="https://colab.research.google.com/github/ABmaxplunck/Introduction-to-Pandas-in-Python/blob/main/car_sales_(Intro_to_Pandas).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# pandas have main 2 datatypes.
# (i) series: one dimentional col
# (ii) dataframe: two dimentional. it has row and col

# %%
# importing pandas and give and alias name

import pandas as pd

# %%
# for reading dataset which is comma separated value(CSV) File
# hey! pandas with pd, read this csv file and save it to car_sales
# car_sales or df(data frame)

car_sales =pd.read_csv('/content/drive/MyDrive/Machine Learning /7.1 car-sales.csv')

# %%
# look at the dataframe 
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# If we work at anaconda then For Exporting a dataframe
#car_sales.to_csv("exported-car-sales.csv")

# %% [markdown]
# ## Describe Data

# %%
# ***************************check down********************
# attribute has no bracket
car_sales.dtypes

# function has bracket
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
#info(). information regarding data

car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
#all rows and cols 
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#if I want to see first 5 row
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
#if I want to see last 5 instances of csv file
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# size of the dataset. 10 rows and 5 cols
car_sales.shape
# Out:
# (10, 5)

# %%
# if I want to see number of row just
print("num of rows: ", car_sales.shape[0])
# Out:
# num of rows:  10

# %%
#if I want to see number of col
print("number of col", car_sales.shape[1])
# Out:
# number of col 5

# %%
#print the list or name of the col 
car_sales.columns
print(car_sales.columns)
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
#describe function which will give (count,mean,std,min,quartiles,max).
#describe() gives statical information. describe works only numerical col
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
#Info to start exploring our data and getting some information about it
# info is kind of like index combined with data types 
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
# call statical analysis on your data frame
car_sales.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
# it will give avg of 3 number here 
car_prices = pd.Series([3000,1500,111250])
car_prices.mean()
# Out:
# 38583.333333333336

# %%
# sum up all of the differnt columns values
# let, df= car_sales
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
# selecting single column
car_sales["Doors"].sum()
# Out:
# 40

# %%
len(car_sales)
# Out:
# 10

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#If I want to check missing values exist or not
car_sales.isnull().sum()
# Out:
# Make             0
# Colour           0
# Odometer (KM)    0
# Doors            0
# Price            0
# dtype: int64

# %%
#how many unique values exist
car_sales['Make'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object>

# %%
# 2 main datatypes
# series = 1 dimentional column of the information 
#series takes pyhton list
series = pd.Series(["BMW","Toyota","Honda"]) 
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
colours = pd.Series(["Red","Blue","White"])
colours
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
#dataframe = 2 dimentional
#dataframe takes python dictionary
car_data = pd.DataFrame({"Car make": series,"Colour": colours})
car_data
# Out:
#   Car make Colour
# 0      BMW    Red
# 1   Toyota   Blue
# 2    Honda  White

# %%
# exporting dataframe 
car_sales.to_csv("exported-car-sales.csv", index=False)

# %% [markdown]
# ## Describe Data
# (i). attributes has no bracket. example: df.
# types
# (ii). function has braket.

# %%
# attribute has no bracket
# function has bracket
# data types of the dataframe 

car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
#print the list or name of the column 
#columns is not a function. it is an attribute because it doesn't have bracket
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns 
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#describe function which will give (count,mean,std,min,quartiles,max).
#describe() gives statical information. 
#describe works only numerical column
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
# info 
# info is kind of like index combined with data types 
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
# call statical analysis on your data frame
car_sales.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
# mean on individual series
#it will give average of 3 numbers 
car_prices = pd.Series([3000,1500,111250])
car_prices.mean()
# Out:
# 38583.333333333336

# %%
# sum up of all differnt column 
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
# Select a single column. sum of door column individually
car_sales["Doors"].sum()
# Out:
# 40

# %%
# length of the data frame
len(car_sales)
# Out:
# 10

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Viewing and Selecting Data

# %%
# head() returns top 5 rows of the data frame. if I want to see first 5 row
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
#if I want to see last/bottom 5(five) instances of csv file
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# .loc function and .iloc function

#.loc = location & .iloc
# let's create a Series so that we can demonstrate the difference between loc and iloc
animals = pd.Series(["cat","dog","bird","panda","snake"]) #create a series
animals
# Out:
# 0      cat
# 1      dog
# 2     bird
# 3    panda
# 4    snake
# dtype: object

# %%
# create a Series with custom index
animals = pd.Series(["cat","dog","bird","panda","snake"], index = [0,3,9,8,3] )
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
# .loc refers to index numbers
# .iloc refers to position 
animals.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animals.loc[9]
# Out:
# 'bird'

# %%
# .loc refers to index 
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# .iloc refers to position 
animals.iloc[3]
# Out:
# 'panda'

# %%
# give items of animals upto position 3
# slicing upto 3
# iloc doesn't include position 3
animals.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 9    bird
# dtype: object

# %%
# .loc refers to index
# it gives us upto includeing index 3
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
# select "Make" column. line 32 and 35 code same
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
# using dot notation
car_sales.Make # or car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
# select "Color" column.
car_sales["Colour"]
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
#select single column with little bit filer
# hey pandas give us car_sales dataframe and this condition is I only want the car_sales data in the make column which are equal to Toyota 
car_sales[car_sales["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#crosstab

#crosstab is used for compare 2 column 
#example: BMW has a 1 car which has 5 doors 
pd.crosstab(car_sales["Make"],car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# Groupby
# If I want to compare more column in a context of another
car_sales.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
#plot function in pandas
car_sales["Odometer (KM)"].plot()

# %%
#histrogram. If I want to see the distribution
car_sales["Odometer (KM)"].hist()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# datatype change for Price column 
# df['Price'] = df['Price'].astype(int)
# print (df)
#df['Price'] = df['Price'].astype(int)


#car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]','').astype(int)
car_sales.Price.replace('\D', '', regex=True).astype(int)
# Out:
# 0     400000
# 1     500000
# 2     700000
# 3    2200000
# 4     350000
# 5     450000
# 6     750000
# 7     700000
# 8     625000
# 9     970000
# Name: Price, dtype: int64

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-274-83bf2f29b5a6> in <module>()
# ----> 1 car_sales["Price"].plot()
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     284     def generate(self):
# ...

# %% [markdown]
# # Manipulating Data

# %%
# string method
# lower() method - which will lower the string 

car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
#from dataframe we can see string are not at lower Case
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# If I want to change the column permanently we have to reassign the column 

car_sales["Make"] = car_sales["Make"].str.lower()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  toyota  White         150043      4   $4,000.00
# 1   honda    Red          87899      4   $5,000.00
# 2  toyota   Blue          32549      3   $7,000.00
# 3     bmw  Black          11179      5  $22,000.00
# 4  nissan  White         213095      4   $3,500.00
# 5  toyota  Green          99213      4   $4,500.00
# 6   honda   Blue          45698      4   $7,500.00
# 7   honda   Blue          54738      4   $7,000.00
# 8  toyota  White          60000      4   $6,250.00
# 9  nissan  White          31600      4   $9,700.00

# %%
# in real life data we may face missing data 

# Missing values csv file import
# Want to see missing values
# pandas descrive missing data with NAN(not a number)
car_sales_missing = pd.read_csv('/content/drive/MyDrive/Machine Learning /9.2 car-sales-missing-data.csv') 
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
# finding mean of the existing Odometer
car_sales_missing["Odometer"].mean()
# Out:
# 92302.66666666667

# %%
# we can fill the NAN values with the mean of the rest of the odometer 
# we can fill the missing values with the odometers mean value 

car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
# if I want to view the dataframe
# still NAN available 
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].mean # want to fiil the missing values with mean value
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0    150043.0
# 1     87899.0
# 2         NaN
# 3     11179.0
# 4    213095.0
# 5         NaN
# 6         NaN
# 7         NaN
# 8     60000.0
# 9     31600.0
# Name: Odometer, dtype: float64>

# %%
# if I want to fill "Odometer" missing values 
# we will look inplace parameter so 
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(), inplace=True)

# %%
# "Odometer" missing values have filled
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
# if I want to drop missing values 
car_sales_missing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing.dropna(inplace=True)
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
# here is a probblem to read the data. have to fix it 
car_sales_missing_dropped.to_csv("car-sales-missing-dropped.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-273-0bdc4016e48a> in <module>()
#       1 # here is a probblem to read the data. have to fix it
# ----> 2 car_sales_missing_dropped.to_csv("car-sales-missing-dropped.csv")
#
# NameError: name 'car_sales_missing_dropped' is not defined

# %%
# 6.10
# column from series
#create data
seats_column = pd.Series([5,5,5,5,5])

# new column called seats 
# we create a new column seats at right side 
car_sales["Seats"] = seats_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  toyota  White         150043      4   $4,000.00    5.0
# 1   honda    Red          87899      4   $5,000.00    5.0
# 2  toyota   Blue          32549      3   $7,000.00    5.0
# 3     bmw  Black          11179      5  $22,000.00    5.0
# 4  nissan  White         213095      4   $3,500.00    5.0
# 5  toyota  Green          99213      4   $4,500.00    NaN
# 6   honda   Blue          45698      4   $7,500.00    NaN
# 7   honda   Blue          54738      4   $7,000.00    NaN
# 8  toyota  White          60000      4   $6,250.00    NaN
# 9  nissan  White          31600      4   $9,700.00    NaN

# %%
#if I want to fill NaN values with 5 seats 
car_sales["Seats"].fillna(5, inplace=True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  toyota  White         150043      4   $4,000.00    5.0
# 1   honda    Red          87899      4   $5,000.00    5.0
# 2  toyota   Blue          32549      3   $7,000.00    5.0
# 3     bmw  Black          11179      5  $22,000.00    5.0
# 4  nissan  White         213095      4   $3,500.00    5.0
# 5  toyota  Green          99213      4   $4,500.00    5.0
# 6   honda   Blue          45698      4   $7,500.00    5.0
# 7   honda   Blue          54738      4   $7,000.00    5.0
# 8  toyota  White          60000      4   $6,250.00    5.0
# 9  nissan  White          31600      4   $9,700.00    5.0

# %%
# column from python list
fuel_economy = [7.5, 9.2, 5.0, 9.6, 8.7, 4.7, 7.6, 8.7, 3.0, 4.5]
car_sales["Fuel per 100KM"] = fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM
# 0  toyota  White         150043      4   $4,000.00    5.0             7.5
# 1   honda    Red          87899      4   $5,000.00    5.0             9.2
# 2  toyota   Blue          32549      3   $7,000.00    5.0             5.0
# 3     bmw  Black          11179      5  $22,000.00    5.0             9.6
# 4  nissan  White         213095      4   $3,500.00    5.0             8.7
# 5  toyota  Green          99213      4   $4,500.00    5.0             4.7
# 6   honda   Blue          45698      4   $7,500.00    5.0             7.6
# 7   honda   Blue          54738      4   $7,000.00    5.0             8.7
# 8  toyota  White          60000      4   $6,250.00    5.0             3.0
# 9  nissan  White          31600      4   $9,700.00    5.0             4.5

# %%
# how many liters of fuel this car is used in its whole entire life 
car_sales["Total fuel used (Liter)"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel per 100KM"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   $4,000.00    5.0             7.5
# 1   honda    Red          87899      4   $5,000.00    5.0             9.2
# 2  toyota   Blue          32549      3   $7,000.00    5.0             5.0
# 3     bmw  Black          11179      5  $22,000.00    5.0             9.6
# 4  nissan  White         213095      4   $3,500.00    5.0             8.7
# 5  toyota  Green          99213      4   $4,500.00    5.0             4.7
# 6   honda   Blue          45698      4   $7,500.00    5.0             7.6
# 7   honda   Blue          54738      4   $7,000.00    5.0             8.7
# 8  toyota  White          60000      4   $6,250.00    5.0             3.0
# 9  nissan  White          31600      4   $9,700.00    5.0             4.5
#
#    Total fuel used (Liter)
# 0                11253.225
# 1                 8086.708
# 2                 1627.450
# 3                 1073.184
# ...

# %%
# Create a column from a single value
car_sales["Number of wheels"] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   $4,000.00    5.0             7.5
# 1   honda    Red          87899      4   $5,000.00    5.0             9.2
# 2  toyota   Blue          32549      3   $7,000.00    5.0             5.0
# 3     bmw  Black          11179      5  $22,000.00    5.0             9.6
# 4  nissan  White         213095      4   $3,500.00    5.0             8.7
# 5  toyota  Green          99213      4   $4,500.00    5.0             4.7
# 6   honda   Blue          45698      4   $7,500.00    5.0             7.6
# 7   honda   Blue          54738      4   $7,000.00    5.0             8.7
# 8  toyota  White          60000      4   $6,250.00    5.0             3.0
# 9  nissan  White          31600      4   $9,700.00    5.0             4.5
#
#    Total fuel used (Liter)  Number of wheels
# 0                11253.225                 4
# 1                 8086.708                 4
# ...

# %%
# add new colum which is road safety
car_sales["Passed road safety"] = True
car_sales.dtypes
# Out:
# Make                        object
# Colour                      object
# Odometer (KM)                int64
# Doors                        int64
# Price                       object
# Seats                      float64
# Fuel per 100KM             float64
# Total fuel used (Liter)    float64
# Number of wheels             int64
# Passed road safety            bool
# dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   $4,000.00    5.0             7.5
# 1   honda    Red          87899      4   $5,000.00    5.0             9.2
# 2  toyota   Blue          32549      3   $7,000.00    5.0             5.0
# 3     bmw  Black          11179      5  $22,000.00    5.0             9.6
# 4  nissan  White         213095      4   $3,500.00    5.0             8.7
# 5  toyota  Green          99213      4   $4,500.00    5.0             4.7
# 6   honda   Blue          45698      4   $7,500.00    5.0             7.6
# 7   honda   Blue          54738      4   $7,000.00    5.0             8.7
# 8  toyota  White          60000      4   $6,250.00    5.0             3.0
# 9  nissan  White          31600      4   $9,700.00    5.0             4.5
#
#    Total fuel used (Liter)  Number of wheels  Passed road safety
# 0                11253.225                 4                True
# ...

# %%
# drop column
car_sales = car_sales.drop["Passed road safety"]
car_sales
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-272-8b8d7e040400> in <module>()
#       1 # drop column
# ----> 2 car_sales = car_sales.drop["Passed road safety"]
#       3 car_sales
#
# TypeError: 'method' object is not subscriptable

# %%
# have to do again 6.11 there are some problem here
# 6.11 will start 

# take a sample from the dataframe with frac parameter which is fraction
# if we want to suffle the data 
car_sales.sample(frac=0.5)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   $4,000.00    5.0             7.5
# 8  toyota  White          60000      4   $6,250.00    5.0             3.0
# 3     bmw  Black          11179      5  $22,000.00    5.0             9.6
# 1   honda    Red          87899      4   $5,000.00    5.0             9.2
# 2  toyota   Blue          32549      3   $7,000.00    5.0             5.0
#
#    Total fuel used (Liter)  Number of wheels  Passed road safety
# 0                11253.225                 4                True
# 8                 1800.000                 4                True
# 3                 1073.184                 4                True
# 1                 8086.708                 4                True
# 2                 1627.450                 4                True

# %%
car_sales_shuffled = car_sales.sample(frac= 1)
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM  \
# 7   honda   Blue          54738      4   $7,000.00    5.0             8.7
# 5  toyota  Green          99213      4   $4,500.00    5.0             4.7
# 6   honda   Blue          45698      4   $7,500.00    5.0             7.6
# 2  toyota   Blue          32549      3   $7,000.00    5.0             5.0
# 3     bmw  Black          11179      5  $22,000.00    5.0             9.6
# 4  nissan  White         213095      4   $3,500.00    5.0             8.7
# 9  nissan  White          31600      4   $9,700.00    5.0             4.5
# 1   honda    Red          87899      4   $5,000.00    5.0             9.2
# 8  toyota  White          60000      4   $6,250.00    5.0             3.0
# 0  toyota  White         150043      4   $4,000.00    5.0             7.5
#
#    Total fuel used (Liter)  Number of wheels  Passed road safety
# 7                 4762.206                 4                True
# ...

# %%
# only select 20% of data
car_sales_shuffled.sample(frac=0.2)
# Out:
#     Make Colour  Odometer (KM)  Doors      Price  Seats  Fuel per 100KM  \
# 7  honda   Blue          54738      4  $7,000.00    5.0             8.7
# 6  honda   Blue          45698      4  $7,500.00    5.0             7.6
#
#    Total fuel used (Liter)  Number of wheels  Passed road safety
# 7                 4762.206                 4                True
# 6                 3473.048                 4                True

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM  \
# 7   honda   Blue          54738      4   $7,000.00    5.0             8.7
# 5  toyota  Green          99213      4   $4,500.00    5.0             4.7
# 6   honda   Blue          45698      4   $7,500.00    5.0             7.6
# 2  toyota   Blue          32549      3   $7,000.00    5.0             5.0
# 3     bmw  Black          11179      5  $22,000.00    5.0             9.6
# 4  nissan  White         213095      4   $3,500.00    5.0             8.7
# 9  nissan  White          31600      4   $9,700.00    5.0             4.5
# 1   honda    Red          87899      4   $5,000.00    5.0             9.2
# 8  toyota  White          60000      4   $6,250.00    5.0             3.0
# 0  toyota  White         150043      4   $4,000.00    5.0             7.5
#
#    Total fuel used (Liter)  Number of wheels  Passed road safety
# 7                 4762.206                 4                True
# ...

# %%
# reset_index function
car_sales_shuffled.reset_index(drop=True, inplace=True)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM  \
# 0   honda   Blue          54738      4   $7,000.00    5.0             8.7
# 1  toyota  Green          99213      4   $4,500.00    5.0             4.7
# 2   honda   Blue          45698      4   $7,500.00    5.0             7.6
# 3  toyota   Blue          32549      3   $7,000.00    5.0             5.0
# 4     bmw  Black          11179      5  $22,000.00    5.0             9.6
# 5  nissan  White         213095      4   $3,500.00    5.0             8.7
# 6  nissan  White          31600      4   $9,700.00    5.0             4.5
# 7   honda    Red          87899      4   $5,000.00    5.0             9.2
# 8  toyota  White          60000      4   $6,250.00    5.0             3.0
# 9  toyota  White         150043      4   $4,000.00    5.0             7.5
#
#    Total fuel used (Liter)  Number of wheels  Passed road safety
# 0                 4762.206                 4                True
# ...

# %%
# 1 mile = 1.6 km
# apply function. it let you apply some kind of function whether it be Numpy or Lambda to a certain column 

car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x: x / 1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM  \
# 0  toyota  White      93776.875      4   $4,000.00    5.0             7.5
# 1   honda    Red      54936.875      4   $5,000.00    5.0             9.2
# 2  toyota   Blue      20343.125      3   $7,000.00    5.0             5.0
# 3     bmw  Black       6986.875      5  $22,000.00    5.0             9.6
# 4  nissan  White     133184.375      4   $3,500.00    5.0             8.7
# 5  toyota  Green      62008.125      4   $4,500.00    5.0             4.7
# 6   honda   Blue      28561.250      4   $7,500.00    5.0             7.6
# 7   honda   Blue      34211.250      4   $7,000.00    5.0             8.7
# 8  toyota  White      37500.000      4   $6,250.00    5.0             3.0
# 9  nissan  White      19750.000      4   $9,700.00    5.0             4.5
#
#    Total fuel used (Liter)  Number of wheels  Passed road safety
# 0                11253.225                 4                True
# ...
